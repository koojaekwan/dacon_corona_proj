# %% [markdown]
# # 코로나바이러스감염증 19  (COVID-19)

# %% [markdown]
# 코로나바이러스 감염증-19 (약칭:COVID-19) 는 SARS-CoV-2 바이러스에 의해 발병하는 급성 호흡기 질환이다. SARS-CoV-2 는 2003년 사스, 2015년 메르스 바이러스와 같이 코로나바이러스 계열의 변종이다. 2019년 12월 12일 최초 보고되었으며 , 보고 내용에 따르면 2019년 12월 1일 중국 후베이성 우한시에서 첫 환자가 생겼다. 그러나 최초 발생 원인과 바이러스 전파 경로는 아직까지도 정확하게 밝혀지지 않았다.
#
# 2020년 1월부터는 전 세계로 퍼지기 시작하여, 남극과 일부 국가와 섬을 제외한 지구상 모든 대륙으로 확산되며 많은 감염자와 사망자를 기록하고 있다. 세계보건기구(WHO)는 2020년 1월 31일, 국제적 공중보건 비상사태를 선포했고, 2월 28일부로 코로나19의 전 세계 위험도를 **‘매우 높음’**으로 격상하였으며, 3월 11일 마침내 범유행전염병임을 선언했다.
#
# <br>

# %% [markdown]
# 미국질병통제예방센터에 따르면 잠복기는 2일에서 14일로, 평균 7일이다. 다만 이는 같은 코로나 바이러스의 일종이던 MERS를 참고로 한 것이기 때문에 정확하다고 보긴 힘들고, 이후 조사에서 SARS와 약 80%가 일치한다고 밝혀짐으로써 메르스보다는 전체적으로 사스와 유사할 가능성이 더 높다. 사스의 잠복기는 대략 2~7일이고 드물게 10일 전후까지 잠복되는 경우도 있다. 즉 메르스보다는 평균 사흘 정도 짧은 잠복기를 가진다.
#
# 초기 41명의 입원 환자들을 대상으로 발표된 연구에 따르면 보고된 증상은 발열(98%), 기침(76%), 호흡곤란(55%), 근육통(44%), 가래(28%), 두통(8%), 객혈(5%)이었다. 증상 모두가 너무 비특이적인 상기도 감염 증상들이어서, 환절기 감기와 혼동하지 않게 조심해야 한다. 또한 혈액 검사상 림프구 감소증(63%)과 백혈구 감소증(25%)이 나타난 사례도 있다.
#
# 지역별로 집계된 보고서에 따르면 후베이성에서의 치사율은 5%에 달할 정도로 높으나 이는 감염자가 많아서 의료시설이 포화상태에 이르러 치료가 제때 이루어지지 않아 높은 걸로 보이며 그 이외의 지역에서는 치사율 0.16%로 낮았다. 또한 중국은 증상이 약한 감염자는 집계하지 않기 때문에 치사율이 더 높게 보이는 것이라고 한다. 하지만 대한민국의 의료진은 감염력은 높다고 밝혔다.

# %% [markdown]
# ![](../image/corona_image2.jpg)
#
# <br>
# <br>

# %% [markdown]
# ## 국내 동향

# %% [markdown]
# 코로나 19가 중국에서 처음 발생한 이후 한국에서는 1월 20일 첫 번째 확진자가 발생하고 2월 16일까지 30명의 확진자가 발생하였다. 확진자 증가 추세가 하루에 한두 명 수준이고 확진자의 동선 정보 공개도 바로바로 되었다. 게다가 당시 소수의 확진자는 수도권 지방 위주로 발생하고 있었고 대구광역시와 경상북도 지방은 단 1명의 확진자도 발생하지 않던 코로나 청정지역이었다. 이 때까지는 확실히 잘 대응하고 있는 것으로 보였으나 2월 18일 31번째 확진자가 나타나면서 상황이 급변하였다.
#
# 신천지 신도로 밝혀진 31번 환자가 나타난 뒤, 바로 다음 날 20명의 추가 확진자가 발생하면서 대구 경북 지역의 신천지 교인을 중심으로 대량 확진자가 발생하기 시작하였다. 이로 인해 30명에서 소강 상태였던 확진자 수가 9천명 가까이 치솟았으며, 유럽 및 미국의 확진자 수가 폭증하기 시작한 3월 이전까지는 확진자 수 순위가 중국에 이은 세계 2위, 인구 수 대비로는 세계 1위까지 올라가기도 했다.
#
# 이후 직장, 예배, 사교적 모임 등 부분적으로 집단감염이 일어나고 있는 추세이다.
#
# <br>
# 관련 홈페이지는 다음을 참고하면 된다.
# * [코로나19(COVID-19) 실시간 상황판](https://coronaboard.kr/)
# * [코로나바이러스감염증-19(COVID-19)](http://ncov.mohw.go.kr/index.jsp)

# %% [markdown]
# ## Library

# %%
# manuluplate
library(tidyverse)
library(data.table)
library(lubridate)   # date


# visualization|
library(plotly)
library(maps)
library(geosphere)  # network map
library(visNetwork) # network map
library(networkD3) # network map

library(formattable)
library(DT)         # datatable
library(ggthemes)   # more themes for ggplot

# map
library(leaflet) 

# html
library(htmlwidgets)  # html render in jupyter notebook
library(IRdisplay)    # html render in jupyter notebook
# Out:
# Attaching package: 'leaflet'
#
# The following object is masked from 'package:networkD3':
#
#     JS

# %% [markdown]
# ## 1.1 Dataset

# %%
case <- fread("../data/Case.csv", data.table = F)
patientinfo <- fread("../data/PatientInfo.csv", data.table = F)
patientroute <- fread("../data/PatientRoute.csv", data.table = F)

# %%
glimpse(patientinfo)
# Out:
# Observations: 2,243
# Variables: 18
# $ patient_id         <int64> 1000000001, 1000000002, 1000000003, 1000000004...
# $ global_num         <int> 2, 5, 6, 7, 9, 10, 11, 13, 19, 21, 23, 24, 29, 3...
# $ sex                <chr> "male", "male", "male", "male", "female", "femal...
# $ birth_year         <int> 1964, 1987, 1964, 1991, 1992, 1966, 1995, 1992, ...
# $ age                <chr> "50s", "30s", "50s", "20s", "20s", "50s", "20s",...
# $ country            <chr> "Korea", "Korea", "Korea", "Korea", "Korea", "Ko...
# $ province           <chr> "Seoul", "Seoul", "Seoul", "Seoul", "Seoul", "Se...
# $ city               <chr> "Gangseo-gu", "Jungnang-gu", "Jongno-gu", "Mapo-...
# $ disease            <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, ...
# $ infection_case     <chr> "overseas inflow", "overseas inflow", "contact w...
# $ infection_order    <int> 1, 1, 2, 1, 2, 3, 3, 1, 2, 3, 1, 1, 4, 5, NA, 4,...
# ...

# %%
glimpse(case)
# Out:
# Observations: 81
# Variables: 8
# $ case_id        <int> 1000001, 1000002, 1000003, 1000004, 1000005, 1000006...
# $ province       <chr> "Seoul", "Seoul", "Seoul", "Seoul", "Seoul", "Seoul"...
# $ city           <chr> "Guro-gu", "Dongdaemun-gu", "Eunpyeong-gu", "Seongdo...
# $ group          <lgl> TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, FALSE, TRU...
# $ infection_case <chr> "Guro-gu Call Center", "Dongan Church", "Eunpyeong S...
# $ confirmed      <int> 79, 24, 14, 13, 10, 7, 6, 65, 34, 8, 6, 6, 4, 1, 32,...
# $ latitude       <chr> "37.508163", "37.592888", "37.63369", "37.55713", "3...
# $ longitude      <chr> "126.884387", "127.056766", "126.9165", "127.0403", ...

# %%
case$case_id <- as.factor(case$case_id)
case$latitude <- as.integer(case$latitude)
case$longitude <- as.integer(case$longitude)

# %% [markdown]
# ## 1.2 Preprocessing

# %% [markdown]
# ### 1.2.1 Cleaning

# %%
apply(case, 2, function(x) sum(is.na(x)))    # NA 확인
apply(case, 2, function(x) sum(is.null(x)))  # NULL 확인
      
#apply(case, 2,function(x) unique(x))  # unique value들 변수별 확인  -> "-"가 NA값으로 존재함을 확인
# Out:
#        case_id       province           city          group infection_case
#              0              0              0              0              0
#      confirmed       latitude      longitude
#              0              0              0
#        case_id       province           city          group infection_case
#              0              0              0              0              0
#      confirmed       latitude      longitude
#              0              0              0

# %%
case[case=="-"]<-NA  # "-"를 NA로 대체

# %%
datatable(case, caption = 'Table : whole data',
          filter = 'top', options = list(pageLength = 10, autoWidth = TRUE))
# Out:
# HTML widgets cannot be represented in plain text (need html)

# %% [markdown]
# ## 1.3.1 감염장소 순위

# %%
options(repr.plot.width = 10, repr.plot.height = 10, repr.plot.res = 300)   # plot size in jupyter R kernel / repr.plot.res = 300 : 화질


temp <- case %>% group_by(infection_case) %>% summarise(n=n()) %>% arrange(-n)

fig <- temp %>% 
    ggplot(aes(x=reorder(infection_case,n), y=n, 
               fill=factor(ifelse(infection_case=="Shincheonji Church","Highlighted","Normal")))) + 
    geom_bar(stat="identity", show.legend = F) +
    scale_fill_manual(name = "infection_case", values=c("red","grey50")) +

    xlab('감염사례') + ylab('수') +
    geom_text(aes(label = n), position=position_dodge(width=0.9), vjust=0.25, hjust=-0.05, col="red") +
    coord_flip() + theme_bw() + ggtitle("각 도시에서 어떤 이유때문에 감염이 발생했는지")


fig
# Out:
# plot without title

# %% [markdown]
# 각 도시에서 어떤 이유때문에 감염환자들이 발생하였는지를 나타내었다.
# 기타장소가 많긴하지만, 기타장소를 제외하고는 신천지 교회에서의 감염이 가장 많이 언급되고 있다.
# 환자와의 접촉, 해외유입 등 다른 사례도 적지않게 존재한다.

# %% [markdown]
# ## 1.3.2 감염장소 확진환자

# %%
options(repr.plot.width = 10, repr.plot.height = 10, repr.plot.res = 300)

temp <- case %>% group_by(infection_case) %>% summarise(n=sum(confirmed)) %>% arrange(-n)

fig <- temp %>% 
    ggplot(aes(x=reorder(infection_case,n), y=n, 
               fill=factor(ifelse(infection_case=="Shincheonji Church","Highlighted","Normal")))) + 
    geom_bar(stat="identity", show.legend = F) +
    scale_fill_manual(name = "infection_case", values=c("red","grey50")) +
    scale_x_discrete(drop=FALSE) + scale_y_continuous(breaks=seq(0,5500,1000),limits=c(0, 5500)) +

    labs(title = "", x = "감염사례", y = "수") +
    geom_text(aes(label = n), position=position_dodge(width=0.9), vjust=0.25, hjust=-0.05, col="red") +
    coord_flip() + theme_bw()


fig
# Out:
# plot without title

# %%
options(repr.plot.width = 9, repr.plot.height = 5, repr.plot.res = 300) 

case %>% group_by(group) %>% summarise(Confirmed=sum(confirmed)) %>% 
    ggplot(aes(x=group, y=Confirmed, fill=group)) + geom_bar(stat="identity",) +
    geom_text(aes(label = Confirmed), position=position_dodge(width=0.9), col="black", size=6) +

    guides(fill=guide_legend(title="집단감염 유무")) +
    theme_bw() + ggtitle("집단감염 유무에 따른 확진자 수")
# Out:
# plot without title

# %% [markdown]
# ## 2.1.1 Cleaning the PatientInfo data

# %%
# "<NA>" -> NA
patientinfo$global_num <- gsub("<NA>",NA, patientinfo$global_num)
patientinfo$birth_year <- gsub("<NA>",NA, patientinfo$birth_year)
patientinfo$disease <- gsub("<NA>",NA, patientinfo$disease)
patientinfo$infection_order <- gsub("<NA>",NA, patientinfo$infection_order)
patientinfo$infected_by <- gsub("<NA>",NA, patientinfo$infected_by)
patientinfo$contact_number <- gsub("<NA>",NA, patientinfo$contact_number)

patientinfo[patientinfo==""]<-NA   # "" -> NA

# %%
unique(patientinfo$sex)

is.space <- function(x) ifelse(x=="",1,0)
sapply(patientinfo, function(x) sum(is.space(x), na.rm = TRUE))
# Out:
# [1] "male"   "female" NA
#         patient_id         global_num                sex         birth_year
#                  0                  0                  0                  0
#                age            country           province               city
#                  0                  0                  0                  0
#            disease     infection_case    infection_order        infected_by
#                  0                  0                  0                  0
#     contact_number symptom_onset_date     confirmed_date      released_date
#                  0                  0                  0                  0
#      deceased_date              state
#                  0                  0

# %% [markdown]
# ## 2.2.1 성별

# %%
options(repr.plot.width = 9, repr.plot.height = 5, repr.plot.res = 300)  

patientinfo %>% group_by(sex) %>% summarise(n=n()) %>% 
ggplot(aes(x=sex, y=n, fill=sex)) + geom_bar(stat="identity") + 
geom_text(aes(label = n), position=position_dodge(width=0.9), vjust = 0.5,  col="black", size = 6) +

labs(title = "", x = "sex", y = "수") +
guides(fill=guide_legend(title="성별")) +
theme_bw()
# Out:
# plot without title

# %% [markdown]
# ## 1.4 감염장소와 확진자 네트워크 시각화

# %%
#Interactive plot으로 확대, 축소가 가능하고 클릭하거나 끌고다닐 수도 있다.
patientinfo
temp_id<-1:nrow(case)

nodes_dat <- data.frame(id = 1:max(temp_id),
                        label = paste0("Case ID" , case$case_id), 
                        color = "black", size=25)

len<-case$infection_case %>% as.factor %>% levels %>% length

nodes_dat2 <- data.frame(id = (max(temp_id)+1):(max(temp_id)+len),
                         label = case$infection_case %>% as.factor %>% levels,
                         color="skyblue", size=13)

nodes_dat<-rbind(nodes_dat, nodes_dat2)
edges_dat <- data.frame(from = temp_id, to = case$infection_case %>% as.factor %>% as.numeric+length(1:max(temp_id)))


visNetwork(nodes = nodes_dat, edges = edges_dat) %>% 
  visEdges(arrows ="") %>% 
  visOptions(highlightNearest = TRUE, nodesIdSelection = TRUE) %>% 
  
  visNodes(color = list(background = "", 
                        border = "darkblue",
                        highlight = ""),
           shadow = list(enabled = TRUE, size = 10))  %>%
  visLayout(randomSeed = 12)
# Out:
#      patient_id global_num sex    birth_year age country province
# 1    1000000001 2          male   1964       50s Korea   Seoul
# 2    1000000002 5          male   1987       30s Korea   Seoul
# 3    1000000003 6          male   1964       50s Korea   Seoul
# 4    1000000004 7          male   1991       20s Korea   Seoul
# 5    1000000005 9          female 1992       20s Korea   Seoul
# 6    1000000006 10         female 1966       50s Korea   Seoul
# 7    1000000007 11         male   1995       20s Korea   Seoul
# 8    1000000008 13         male   1992       20s Korea   Seoul
# 9    1000000009 19         male   1983       30s Korea   Seoul
# 10   1000000010 21         female 1960       60s Korea   Seoul
# 11   1000000011 23         female 1962       50s China   Seoul
# 12   1000000012 24         male   1992       20s Korea   Seoul
# 13   1000000013 29         male   1938       80s Korea   Seoul
# 14   1000000014 30         female 1952       60s Korea   Seoul
# ...

# %%
temp <- case %>% group_by(infection_case) %>% summarise(n=sum(confirmed))
temp %>% left_join(case)


leaflet() %>% 
addTiles() %>% 
addCircleMarkers(data=temp %>% left_join(case),
                   ~longitude, ~latitude,
                radius = ~sqrt(n), opacity = 0.3, 
                fillOpacity = 0.2)
# Out:
# Joining, by = "infection_case"
#     infection_case                   n    case_id province
# 1   Bonghwa Pureun Nursing Home        58 6000003 Gyeongsangbuk-do
# 2   Bundang Jesaeng Hospital           22 2000003 Gyeonggi-do
# 3   Changnyeong Coin Karaoke            7 6100005 Gyeongsangnam-do
# 4   Cheongdo Daenam Hospital          122 1100006 Busan
# 5   Cheongdo Daenam Hospital          122 1200003 Daegu
# 6   Cheongdo Daenam Hospital          122 6000002 Gyeongsangbuk-do
# 7   contact with patient              681 1200002 Daegu
# 8   contact with patient              681 1300002 Gwangju
# 9   contact with patient              681 1400002 Incheon
# 10  contact with patient              681 1500001 Daejeon
# 11  contact with patient              681 1600002 Ulsan
# 12  contact with patient              681 4000003 Chungcheongbuk-do
# 13  contact with patient              681 5000001 Jeollabuk-do
# 14  contact with patient              681 5100003 Jeollanam-do
# ...
